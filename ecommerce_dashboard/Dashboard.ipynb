# %%
#Libraries
import pandas as pd
import panel as pn
import numpy as np
import psycopg2
pn.extension('tabulator')

import hvplot.pandas
from holoviews import opts
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='5b3da2b0-11de-4138-bb02-a243aa4086f7'>
#   <div id="e86de5d3-3ee3-464b-a38c-ea8d5173be29" data-root-id="5b3da2b0-11de-4138-bb02-a243aa4086f7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"44d0f03d-83ed-493e-85f0-4737e2472c08":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"5b3da2b0-11de-4138-bb02-a243aa4086f7"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"c9ad016e-a57f-44b7-ba44-14fee13d30d2","attributes":{"plot_id":"5b3da2b0-11de-4138-bb02-a243aa4086f7","comm_id":"367b18378d204b0f8b40017670174e1a","client_comm_id":"5aa909a87e3d4755b247cb0ec48134a0"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"44d0f03d-83ed-493e-85f0-4737e2472c08","roots":{"5b3da2b0-11de-4138-bb02-a243aa4086f7":"e86de5d3-3ee3-464b-a38c-ea8d5173be29"},"root_ids":["5b3da2b0-11de-4138-bb02-a243aa4086f7"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Connect to database
conn = psycopg2.connect(
    database = 'E-commerce_analysis',
    user = 'postgres',
    password= 'chan.chano123099',
    host='127.0.0.1',
    port =5000
)
conn.autocommit = True

cur = conn.cursor()

# Get data using queries
def get_data(query, conn):
    df = pd.read_sql_query(query, conn)
    return df
    
sales_profit_query = """
    select
        category,
        to_char(order_date, 'Month') as order_month,
        sum(amount) as monthly_revenue, sum(profit) as monthly_profit
    from order_details
    join list_of_orders On order_details.order_id = list_of_orders.order_id
    Group by category, order_month
    order by monthly_profit DESC
"""
city_sales_query = """
    select city,category,
    	count(category) as number_orders,
    	sum(amount) as Total
    from list_of_orders as A
    join order_details as B ON A.order_id = B.order_id
    group by  city, category
    order by number_orders DESC

"""

sales_product_query = """
    select category, subcategory, sum(amount) as Total_sales 
    from order_details
    group by category, subcategory
    order by total_sales DESC
"""
profit_sales_query = """
    select amount, profit, category, to_char(order_date, 'Month') as order_month
    from order_details as A
    join list_of_orders as B on A.order_id = B.order_id
"""

#All data from database
sales_trend = get_data(sales_profit_query, conn)
city_sales = get_data(city_sales_query , conn)
sales_product = get_data(sales_product_query, conn)
profit_sales = get_data(profit_sales_query, conn)

conn.close()
# Out:
# C:\Users\chano\AppData\Local\Temp\ipykernel_11184\3785893333.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
# Graph for Sales&Profit Trend per month

#Minimal date transformation
sales_trend['order_month'] = sales_trend['order_month'].str.strip()
sales_trend['order_month'] = pd.to_datetime(sales_trend['order_month'], format='%B').dt.month_name().sort_values().str.slice(stop=3)

#Mapping the order_month column for sorting
month_order = {
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4,
    'May': 5, 'Jun': 6, 'Jul': 7, 'Aug': 8,
    'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12
}

# Widgets for category
category = pn.widgets.RadioButtonGroup(name="Category", options=['Electronics', 'Clothing', 'Furniture'], button_type='success')


#Line for graph to become interactive
sales_trend_inter = sales_trend.interactive()

#Pipeline for sales_profit_trend to automatically update the graph
sales_trend_pipeline = sales_trend_inter[
    (sales_trend_inter.category == category )
].groupby(['order_month']).aggregate({'monthly_profit':'sum', 'monthly_revenue':'sum'}).sort_values(by = 'order_month', key=lambda x: x.map(month_order)).reset_index()

# Plotting the graph
trend_plot = sales_trend_pipeline.hvplot(x='order_month', 
                                         line_width = 2, 
                                         title= "Trends",
                                         height = 400, 
                                         width=800, 
                                         xlabel='Months', 
                                         grid=True, 
                                         color=['red','blue'], 
                                         cmap=['monthly_revenue','monthly_profit' ])
trend_plot.opts(legend_labels={'monthly_profit':"Profit", 'monthly_revenue':'Sales'}, legend_position='top_right')
# Out:
# <div id='9e8db7b4-3910-4c17-adee-8d9fdc754450'>
#   <div id="bb4d0e17-1b4d-49d9-b5d2-630c1d22d9d6" data-root-id="9e8db7b4-3910-4c17-adee-8d9fdc754450" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"19d47b25-4c93-4c07-8d7f-30f99d7fe758":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"9e8db7b4-3910-4c17-adee-8d9fdc754450","attributes":{"name":"Row01307","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"247f3cfb-e6bd-4115-a8ff-c4e84e690ce1","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7088071d-4e5d-480e-a4b3-28426ef79163","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"11c51063-5d55-402a-a7e7-963d810ee0cd","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"1e547cd3-0e4e-43d8-ba6b-27de913f2cb3","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"889d5fcf-9620-4701-aaaa-0e9b4437865b","attributes":{"name":"Column01304","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"247f3cfb-e6bd-4115-a8ff-c4e84e690ce1"},{"id":"7088071d-4e5d-480e-a4b3-28426ef79163"},{"id":"11c51063-5d55-402a-a7e7-963d810ee0cd"},{"id":"1e547cd3-0e4e-43d8-ba6b-27de913f2cb3"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"294f0505-1413-40fd-b124-7e61027beaf5","attributes":{"name":"Column01287","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"247f3cfb-e6bd-4115-a8ff-c4e84e690ce1"},{"id":"7088071d-4e5d-480e-a4b3-28426ef79163"},{"id":"11c51063-5d55-402a-a7e7-963d810ee0cd"},{"id":"1e547cd3-0e4e-43d8-ba6b-27de913f2cb3"}],"margin":0,"align":"start","children":[{"type":"object","name":"RadioButtonGroup","id":"d9b10744-57cd-4427-a215-9509f33c4bdf","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"247f3cfb-e6bd-4115-a8ff-c4e84e690ce1"},{"type":"object","name":"ImportedStyleSheet","id":"5b0afc2c-d8e2-4b57-82cb-949d490cface","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/button.css"}},{"id":"11c51063-5d55-402a-a7e7-963d810ee0cd"},{"id":"1e547cd3-0e4e-43d8-ba6b-27de913f2cb3"}],"margin":[5,10],"align":"start","labels":["Electronics","Clothing","Furniture"],"active":0}}]}},{"type":"object","name":"Figure","id":"b2afc5c3-2fec-4b43-8d4e-5cb65461108b","attributes":{"width":800,"height":400,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"6ff51de0-a34f-4f2e-8592-fc9ade7f0d9c","attributes":{"tags":[[["order_month","order_month",null]],[]],"factors":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]}},"y_range":{"type":"object","name":"Range1d","id":"68ac5c87-8c22-4748-9f2a-ed4cf7e3773a","attributes":{"tags":[[["value","value",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":-4412.1,"end":33413.1,"reset_start":-4412.1,"reset_end":33413.1}},"x_scale":{"type":"object","name":"CategoricalScale","id":"ba52592c-cb18-4db0-8356-a3beb6cedb8e"},"y_scale":{"type":"object","name":"LinearScale","id":"5ed3c755-031d-497d-892e-879065a8727f"},"title":{"type":"object","name":"Title","id":"c8b8134b-80fc-45e5-9262-d8c736c715b9","attributes":{"text":"Trends","text_color":"black","text_font_size":"12pt"}} ...

# %%
# Graph for Sales per City

# Widgets for Top 10 and Bottom 10
select = pn.widgets.Select(name='Top or Bottom 10', options={'Bottom 10':True, 'Top 10':False})

#Line for graph to become interactive
city_sales_inter = city_sales.interactive()

#Pipeline for sales per city to automatically update the graph
city_sales_pipeline = city_sales_inter[
    (city_sales_inter.category == category)
].groupby(['city']).sum('total').sort_values(by='total', ascending=select).head(10)

#Plotting the graph
city_sales_plot = city_sales_pipeline.hvplot.bar(x='city', y='total').opts(title='Sales per City',
                                                                           ylabel='Sales', 
                                                                           xlabel='City', 
                                                                           bgcolor='lightgrey', 
                                                                           color='lightblue', 
                                                                           fontscale=1.2,
                                                                           xrotation=45, 
                                                                           height = 400, 
                                                                           width=800)
city_sales_plot
# Out:
# <div id='e572f501-6021-4110-b929-769461e28448'>
#   <div id="ec444730-5771-49f4-8db4-3f2e4ca74147" data-root-id="e572f501-6021-4110-b929-769461e28448" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"cbd9b9f7-a31a-4359-a610-5622ef1b0541":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"e572f501-6021-4110-b929-769461e28448","attributes":{"name":"Row02236","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"86fa2c5a-8a22-476f-bd09-dc94945f3481","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"310ea5e8-6727-4719-b74f-864118e73c6a","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"f897f712-0638-484e-9212-670e089750ab","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"0abb25c1-3135-4d0f-870a-8128f100b6fb","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"f3b306cb-b978-46e3-a313-2578638d4488","attributes":{"name":"Column02233","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"86fa2c5a-8a22-476f-bd09-dc94945f3481"},{"id":"310ea5e8-6727-4719-b74f-864118e73c6a"},{"id":"f897f712-0638-484e-9212-670e089750ab"},{"id":"0abb25c1-3135-4d0f-870a-8128f100b6fb"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"7d0cbc5e-f426-497a-80de-efc9e71c6c84","attributes":{"name":"Column02216","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"86fa2c5a-8a22-476f-bd09-dc94945f3481"},{"id":"310ea5e8-6727-4719-b74f-864118e73c6a"},{"id":"f897f712-0638-484e-9212-670e089750ab"},{"id":"0abb25c1-3135-4d0f-870a-8128f100b6fb"}],"margin":0,"align":"start","children":[{"type":"object","name":"RadioButtonGroup","id":"bf83da8d-de12-4071-a204-d4c497bfc7b0","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"86fa2c5a-8a22-476f-bd09-dc94945f3481"},{"type":"object","name":"ImportedStyleSheet","id":"e78f96d3-34df-4e13-9a06-b5f99db213ea","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/button.css"}},{"id":"f897f712-0638-484e-9212-670e089750ab"},{"id":"0abb25c1-3135-4d0f-870a-8128f100b6fb"}],"margin":[5,10],"align":"start","labels":["Electronics","Clothing","Furniture"],"active":0}},{"type":"object","name":"panel.models.widgets.CustomSelect","id":"054f9426-f156-4a73-bade-0efba4f3892c","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"86fa2c5a-8a22-476f-bd09-dc94945f3481"},{"type":"object","name":"ImportedStyleSheet","id":"6675e500-24e1-4b6d-9b13-e2a236ba46bb","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/select.css"}},{"id":"f897f712-0638-484e-9212-670e089750ab"},{"id":"0abb25c1-3135-4d0f-870a-8128f100b6fb"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Top or Bottom 10","options":[["True","Bottom 10"],["False","Top 10"]],"value":"True"}}]}},{"type":"object","name":"Figure","id":"92af9b08-1eea-4931-b432-200cd243d389","attributes":{"width":800,"height":400,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"c640e791-505f-4189-b3ed-c9b33ca186b9","attr ...

# %%
#Graphs for sales per product

#Line for graph to become interactive
sales_product_inter = sales_product.interactive()

#Pipeline
sales_product_pipeline = sales_product_inter[
   ( sales_product_inter.category == category)
].groupby(['subcategory']).sum('total_sales').sort_values('total_sales', ascending = False)

#Plot
sales_product_plot = sales_product_pipeline.hvplot.barh(x='subcategory', y='total_sales').opts(title='Sales per Product', 
                                                                                               xlabel='Products', 
                                                                                               ylabel='Sales',
                                                                                               height = 400, 
                                                                                               width=800, 
                                                                                               bgcolor = 'lightgrey', 
                                                                                               fontscale=1.2, 
                                                                                               color='lightblue')
sales_product_plot
# Out:
# <div id='10853ed5-2671-465b-8245-53e7293738d8'>
#   <div id="e702f6f3-aab9-4f8f-8dc4-7e2e96401e58" data-root-id="10853ed5-2671-465b-8245-53e7293738d8" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9ba6776c-a922-4238-980c-183761a1fa69":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"10853ed5-2671-465b-8245-53e7293738d8","attributes":{"name":"Row02700","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"482c44f3-e76d-4e83-b665-803172e22382","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"2bb834ec-ba73-420f-b407-390d40e0c018","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"0b8f613c-603f-45ec-baa4-264d6358387a","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"2f91fce5-6e5e-4a11-9343-de0bfe1e1c0d","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"6a32b74d-8d04-4676-bafc-ec3862257ea7","attributes":{"name":"Column02697","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"482c44f3-e76d-4e83-b665-803172e22382"},{"id":"2bb834ec-ba73-420f-b407-390d40e0c018"},{"id":"0b8f613c-603f-45ec-baa4-264d6358387a"},{"id":"2f91fce5-6e5e-4a11-9343-de0bfe1e1c0d"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"72eba1a9-71ad-422a-b92d-e678a5c3d57f","attributes":{"name":"Column02680","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"482c44f3-e76d-4e83-b665-803172e22382"},{"id":"2bb834ec-ba73-420f-b407-390d40e0c018"},{"id":"0b8f613c-603f-45ec-baa4-264d6358387a"},{"id":"2f91fce5-6e5e-4a11-9343-de0bfe1e1c0d"}],"margin":0,"align":"start","children":[{"type":"object","name":"RadioButtonGroup","id":"29dac3d4-26de-4a83-a4ef-dc70bab9f72e","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"482c44f3-e76d-4e83-b665-803172e22382"},{"type":"object","name":"ImportedStyleSheet","id":"a1c7c7aa-ca24-48bf-ae51-9ef34681888a","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/button.css"}},{"id":"0b8f613c-603f-45ec-baa4-264d6358387a"},{"id":"2f91fce5-6e5e-4a11-9343-de0bfe1e1c0d"}],"margin":[5,10],"align":"start","labels":["Electronics","Clothing","Furniture"],"active":0}}]}},{"type":"object","name":"Figure","id":"6391eba7-0d1a-42e5-b399-4c87763bc733","attributes":{"width":800,"height":400,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"638f385f-89e1-46ce-8b5a-ad35d3a6dda1","attributes":{"tags":[[["total_sales","total_sales",null]],[]],"end":61904.4,"reset_start":0.0,"reset_end":61904.4}},"y_range":{"type":"object","name":"FactorRange","id":"6feabb07-f7d3-4beb-aae4-b28172d2a7cf","attributes":{"tags":[[["subcategory","subcategory",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"factors":["Printers","Phones","Electronic Games","Accessories"]}},"x_scale":{"type":"object","name":"LinearScale","id":"7d81c573-ef22-4ccb-8f20-9ebda6c4073f"},"y_scale":{"type":"object","name":"CategoricalScale","id":"f401885f-29f1-4d28-a807-7843aa593d4b"},"title":{"type":"object","name":"Title","id":"8b8809cb-efa6-4d3f-97cd-9af1e8e5916c","attributes":{"text":"Sales per Product","text_color":"black","text_font_size":"14.4pt"}},"renderers":[ ...

# %%
#Graph for scatter Profit vs Sales

#For interactive graph
profit_sales_inter = profit_sales.interactive()

#Pipeline
profit_sales_pipeline = profit_sales_inter[
    (profit_sales_inter.category == category)
]

#Plot
profit_sale_plot = profit_sales_pipeline.hvplot.scatter(x='amount', y='profit', c='order_month').opts(title='Profit VS Sale', 
                                                                                                      width = 800, 
                                                                                                      height=400, 
                                                                                                      fontscale=1.2, 
                                                                                                      xlabel='Sales', 
                                                                                                      ylabel='Profit')
profit_sale_plot
# Out:
# <div id='4cb7bf8d-0b4c-43a0-8580-fb751bb4a93d'>
#   <div id="a1f3915f-c26e-46a5-a2ca-cf52022203b0" data-root-id="4cb7bf8d-0b4c-43a0-8580-fb751bb4a93d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"0bae76b9-dd7b-44f4-939f-2eddfff4f47d":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"4cb7bf8d-0b4c-43a0-8580-fb751bb4a93d","attributes":{"name":"Row04377","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"ae97cf6d-b01e-4355-b15c-c818bb9a3a1b","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"865cff9f-701c-4394-96fa-c7c9cc65253b","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"aca7f24e-8000-4903-9041-df433845d9b5","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"12b7ce24-2513-41b8-81cc-6bed6f8ddb45","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"5a8c6a23-737f-47cd-a94d-f65d525d5ed4","attributes":{"name":"Column04374","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"ae97cf6d-b01e-4355-b15c-c818bb9a3a1b"},{"id":"865cff9f-701c-4394-96fa-c7c9cc65253b"},{"id":"aca7f24e-8000-4903-9041-df433845d9b5"},{"id":"12b7ce24-2513-41b8-81cc-6bed6f8ddb45"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"884ed571-17cd-4ad8-935a-d8d5f6c91dce","attributes":{"name":"Column04357","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"ae97cf6d-b01e-4355-b15c-c818bb9a3a1b"},{"id":"865cff9f-701c-4394-96fa-c7c9cc65253b"},{"id":"aca7f24e-8000-4903-9041-df433845d9b5"},{"id":"12b7ce24-2513-41b8-81cc-6bed6f8ddb45"}],"margin":0,"align":"start","children":[{"type":"object","name":"RadioButtonGroup","id":"8e1070a7-b740-4a3c-be1e-6a80f2ee2123","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"ae97cf6d-b01e-4355-b15c-c818bb9a3a1b"},{"type":"object","name":"ImportedStyleSheet","id":"7e562b4d-1b0c-4cd3-a108-bdc10ff3dea6","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/button.css"}},{"id":"aca7f24e-8000-4903-9041-df433845d9b5"},{"id":"12b7ce24-2513-41b8-81cc-6bed6f8ddb45"}],"margin":[5,10],"align":"start","labels":["Electronics","Clothing","Furniture"],"active":0}}]}},{"type":"object","name":"Figure","id":"991d3679-26f9-4e20-aeeb-30b9916e707d","attributes":{"width":800,"height":400,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"38b958d4-e5ca-45f8-9dd7-84b6615101c1","attributes":{"tags":[[["amount","amount",null]],[]],"start":-186.05,"end":4347.05,"reset_start":-186.05,"reset_end":4347.05}},"y_range":{"type":"object","name":"Range1d","id":"20d33462-57ae-4fab-8db4-920197a29148","attributes":{"tags":[[["profit","profit",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":-1603.1,"end":1998.1,"reset_start":-1603.1,"reset_end":1998.1}},"x_scale":{"type":"object","name":"LinearScale","id":"e993d952-2348-484b-83c9-d65ac35ef905"},"y_scale":{"type":"object","name":"LinearScale","id":"c4f45588-8f77-4547-b199-81ddfc513995"},"title":{"type":"object","name":"Title","id":"62bac503-bd29-4e09-8a26-5a9951add385","attributes":{"text":"Profit VS Sale","text_color":"black","text_font_size":"14.4pt"}},"renderers":[{"type" ...

# %%
#Using template to post in a localhost
template = pn.template.FastListTemplate(
    title = "E-commerce Analysis",
    main = [pn.Row(category, align="center"),
            pn.Row(pn.Column(trend_plot.panel(width=800), 
                             margin=(0,500,0,40)), 
                   pn.Column(profit_sale_plot.panel(width=800), 
                             margin=(0,20,0,0))),
            pn.Row(pn.Column(select, city_sales_plot.panel(width=800), 
                             margin=(0,0,0,40)),
                   sales_product_plot.panel(width=800))
                   ],
    accent_base_color = "#88d8b0",
    header_background = "#88d8b0",
                     
)

template.servable()

#To browse the dashboard. Type this in the terminal "panel serve Dashboard.ipynb"
# Out:
# FastListTemplate
#     [js_area] HTML(None, height=0, margin=0, sizing_mode='fixed', width=0)
#     [actions] TemplateActions()
#     [browser_info] BrowserInfo(dark_mode=True, device_pixel_ratio=0.8999999761581421, language='en-US', timezone='Asia/Shanghai', timezone_offset=-480, webdriver=False)
#     [busy_indicator] LoadingSpinner(height=20, width=20)
#     [1980185239504] Row(align='center')
#         [0] RadioButtonGroup(button_type='success', name='Category', options=['Electronics', ...], value='Electronics')
#     [1980189002480] Row
#         [0] Column(margin=(0, 500, 0, 40))
#             [0] ParamFunction(function, _pane=HoloViews, defer_load=False, width=800)
#         [1] Column(margin=(0, 20, 0, 0))
#             [0] ParamFunction(function, _pane=HoloViews, defer_load=False, width=800)
#     [1980188403600] Row
#         [0] Column(margin=(0, 0, 0, 40))
#             [0] Select(name='Top or Bottom 10', options={'Bottom 10': True, ...}, value=True)
#             [1] ParamFunction(function, _pane=HoloViews, defer_load=False, width=800)
#         [1] ParamFunction(function, _pane=HoloViews, defer_load=False, width=800)
